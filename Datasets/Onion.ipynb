# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

data = pd.read_csv('Onion.csv')

selected_attributes = ['Prices']
data_selected = data[selected_attributes].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data_selected)

time_steps = 20

X = []
y = []
for i in range(len(data_scaled) - time_steps):
    X.append(data_scaled[i:i+time_steps])
    y.append(data_scaled[i+time_steps])
X, y = np.array(X), np.array(y)

split_ratio = 0.8
split_idx = int(split_ratio * len(X))
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(time_steps, len(selected_attributes))))
model.add(Dropout(0.2))
model.add(LSTM(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(selected_attributes)))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

train_predictions_actual = scaler.inverse_transform(train_predictions)
y_train_actual = scaler.inverse_transform(y_train)
test_predictions_actual = scaler.inverse_transform(test_predictions)
y_test_actual = scaler.inverse_transform(y_test)
test_accuracy = model.evaluate(X_test, y_test)
test_accuracy = test_accuracy*100

data['Date'] = data['Date'].astype(str)
vegetable_names = data['Date'][time_steps:].values
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(vegetable_names[:split_idx], y_train_actual, label='Average Price' , color = 'blue')

plt.plot(vegetable_names[split_idx:], y_test_actual, label='Max Price' , color = 'green')

plt.plot(vegetable_names[:split_idx], train_predictions_actual, label='Minimun Price' , color = 'red')

plt.plot(vegetable_names[split_idx:], test_predictions_actual, label='Predicted Price' , color = 'Brown')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Vegetable Price Prediction for Onion')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

print(f"Test Accuracy: {test_accuracy: .2f}%")
# Out:
# Epoch 1/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.3563 - val_loss: 0.6745
# Epoch 2/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3420 - val_loss: 0.6468
# Epoch 3/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3283 - val_loss: 0.6187
# Epoch 4/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3141 - val_loss: 0.5915
# Epoch 5/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3062 - val_loss: 0.5644
# Epoch 6/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.2896 - val_loss: 0.5349
# Epoch 7/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2746 - val_loss: 0.5031
# Epoch 8/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2598 - val_loss: 0.4706
# Epoch 9/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2510 - val_loss: 0.4371
# Epoch 10/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2349 - val_loss: 0.4022
# Epoch 11/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2278 - val_loss: 0.3664
# Epoch 12/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.2048 - val_loss: 0.3279
# Epoch 13/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1869 - val_loss: 0.2866
# Epoch 14/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1702 - val_loss: 0.2434
# Epoch 15/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1520 - val_loss: 0.1986
# Epoch 16/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1370 - val_loss: 0.1532
# Epoch 17/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1109 - val_loss: 0.1082
# Epoch 18/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1166 - val_loss: 0.0670
# Epoch 19/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1042 - val_loss: 0.0338
# Epoch 20/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0984 - val_loss: 0.0144
# Epoch 21/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0973 - val_loss: 0.0082
# Epoch 22/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1262 - val_loss: 0.0072
# Epoch 23/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1198 - val_loss: 0.0072
# Epoch 24/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1222 - val_loss: 0.0084
# Epoch 25/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1178 - val_loss: 0.0132
# Epoch 26/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0882 - val_loss: 0.0215
# Epoch 27/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0977 - val_loss: 0.0326
# Epoch 28/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0949 - val_loss: 0.0443
# Epoch 29/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0953 - val_loss: 0.0552
# Epoch 30/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0958 - val_loss: 0.0650
# Epoch 31/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0919 - val_loss: 0.0730
# Epoch 32/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1056 - val_loss: 0.0793
# Epoch 33/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0932 - val_loss: 0.0835
# Epoch 34/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0884 - val_loss: 0.0852
# Epoch 35/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1079 - val_loss: 0.0853
# Epoch 36/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1109 - val_loss: 0.0835
# Epoch 37/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0892 - val_loss: 0.0801
# Epoch 38/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1043 - val_loss: 0.0747
# Epoch 39/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0894 - val_loss: 0.0677
# Epoch 40/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1043 - val_loss: 0.0604
# Epoch 41/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0943 - val_loss: 0.0533
# Epoch 42/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1035 - val_loss: 0.0466
# Epoch 43/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0904 - val_loss: 0.0407
# Epoch 44/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0937 - val_loss: 0.0370
# Epoch 45/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1002 - val_loss: 0.0351
# Epoch 46/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0801 - val_loss: 0.0335
# Epoch 47/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0815 - val_loss: 0.0335
# Epoch 48/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0912 - val_loss: 0.0360
# Epoch 49/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0908 - val_loss: 0.0405
# Epoch 50/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1066 - val_loss: 0.0459
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0459
# Test Accuracy:  4.59%
