# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

file = input("Enter The vegetable name : ")
data = pd.read_csv(file+'.csv')

selected_attributes = ['Prices']
data_selected = data[selected_attributes].values


scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data_selected)


time_steps = 20

X = []
y = []
for i in range(len(data_scaled) - time_steps):
    X.append(data_scaled[i:i+time_steps])
    y.append(data_scaled[i+time_steps])
X, y = np.array(X), np.array(y)

split_ratio = 0.8
split_idx = int(split_ratio * len(X))
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]


model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(time_steps, len(selected_attributes))))
model.add(Dropout(0.2))
model.add(LSTM(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(selected_attributes)))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))


train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)


train_predictions_actual = scaler.inverse_transform(train_predictions)
y_train_actual = scaler.inverse_transform(y_train)
test_predictions_actual = scaler.inverse_transform(test_predictions)
y_test_actual = scaler.inverse_transform(y_test)
test_accuracy = model.evaluate(X_test, y_test)
test_accuracy = test_accuracy*100


date = data['Date'][time_steps:].values
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

y_train_actual = y_train_actual.flatten()
y_test_actual = y_test_actual.flatten()
train_predictions_actual =  train_predictions_actual.flatten()
train_predictions_actual =  train_predictions_actual.flatten()
    
plt.plot(vegetable_names[:split_idx], y_train_actual, label='Average Price' , color = 'blue')

plt.plot(vegetable_names[split_idx:], y_test_actual, label='Max Price' , color = 'green')

plt.plot(vegetable_names[:split_idx], train_predictions_actual, label='Minimun Price' , color = 'red')

plt.plot(vegetable_names[split_idx:], test_predictions_actual, label='Predicted Price' , color = 'Brown')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Vegetable Price Prediction for Potato')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()
print(f"Test Accuracy: {test_accuracy: .2f}%")
# Out:
# Enter The vegetable name :  Tomato
# Epoch 1/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.4757 - val_loss: 0.7876
# Epoch 2/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4508 - val_loss: 0.7579
# Epoch 3/50
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4306 - val_loss: 0.7279
# Epoch 4/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4141 - val_loss: 0.6914
# Epoch 5/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3952 - val_loss: 0.6530
# Epoch 6/50
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3676 - val_loss: 0.6159
# Epoch 7/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3452 - val_loss: 0.5795
# Epoch 8/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3208 - val_loss: 0.5410
# Epoch 9/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2932 - val_loss: 0.5003
# Epoch 10/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2698 - val_loss: 0.4567
# Epoch 11/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2579 - val_loss: 0.4093
# Epoch 12/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2171 - val_loss: 0.3561
# Epoch 13/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1832 - val_loss: 0.2960
# Epoch 14/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1614 - val_loss: 0.2312
# Epoch 15/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1199 - val_loss: 0.1646
# Epoch 16/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0803 - val_loss: 0.0994
# Epoch 17/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0513 - val_loss: 0.0417
# Epoch 18/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0365 - val_loss: 0.0073
# Epoch 19/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0505 - val_loss: 0.0078
# Epoch 20/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0749 - val_loss: 0.0173
# Epoch 21/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0922 - val_loss: 0.0144
# Epoch 22/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0619 - val_loss: 0.0069
# Epoch 23/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0514 - val_loss: 0.0037
# Epoch 24/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0492 - val_loss: 0.0079
# Epoch 25/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0411 - val_loss: 0.0180
# Epoch 26/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0326 - val_loss: 0.0301
# Epoch 27/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 28/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0369 - val_loss: 0.0534
# Epoch 29/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0390 - val_loss: 0.0617
# Epoch 30/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0441 - val_loss: 0.0672
# Epoch 31/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0446 - val_loss: 0.0694
# Epoch 32/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0355 - val_loss: 0.0683
# Epoch 33/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0635 - val_loss: 0.0652
# Epoch 34/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0507 - val_loss: 0.0597
# Epoch 35/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0542 - val_loss: 0.0527
# Epoch 36/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0354 - val_loss: 0.0451
# Epoch 37/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0403 - val_loss: 0.0375
# Epoch 38/50
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0394 - val_loss: 0.0305
# Epoch 39/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0326 - val_loss: 0.0250
# Epoch 40/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0340 - val_loss: 0.0204
# Epoch 41/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0314 - val_loss: 0.0164
# Epoch 42/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0280 - val_loss: 0.0137
# Epoch 43/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0233 - val_loss: 0.0121
# Epoch 44/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0350 - val_loss: 0.0119
# Epoch 45/50
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0397 - val_loss: 0.0124
# Epoch 46/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0391 - val_loss: 0.0135
# Epoch 47/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0401 - val_loss: 0.0154
# Epoch 48/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0365 - val_loss: 0.0180
# Epoch 49/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0440 - val_loss: 0.0209
# Epoch 50/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0400 - val_loss: 0.0233
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0233
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [92], in <cell line: 69>()
#      65 train_predictions_actual =  train_predictions_actual.flatten()
#      67 plt.plot(vegetable_names[:split_idx], y_train_actual, label='Average Price' , color = 'blue')
# ---> 69 plt.plot(vegetable_names[split_idx:], y_test_actual, label='Max Price' , color = 'green')
#      71 plt.plot(vegetable_names[:split_idx], train_predictions_actual, label='Minimun Price' , color = 'red')
#      73 plt.plot(vegetable_names[split_idx:], test_predictions_actual, label='Predicted Price' , color = 'Brown')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (7,)
